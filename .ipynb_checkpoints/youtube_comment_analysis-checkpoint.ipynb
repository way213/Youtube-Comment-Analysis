# %% [markdown]
# ### This notebook serves to simpify the process of gaining feedback from viewer comments for content creators on youtube.

# %% [markdown]
# * Most popular youtube videos have thousands of comments, and with issues like confirmation bias and more, there is not a fast way to go through comments and reach a conclusion on public sentiment.
# * Here, we will be utilizing the Youtube API to call comments of videos of our choice, and further analyzing the comments of said videos.

# %%
import os
import googleapiclient.discovery

# %%
# here is our API key and other items
youtube_api_key = 'AIzaSyBaFhDvztf8hwgX4DWxTRdbmcqKbEkr6-A'
api_service_name = "youtube"
api_version = "v3"

# create a client object that interacts with the api
youtube = googleapiclient.discovery.build(api_service_name, api_version, developerKey = youtube_api_key)

# %%
# create custom class to store comment details
class comment_details:
    def __init__(self, comment_id, text_display, text_original, like_count):
        self.comment_id = comment_id
        self.text_display = text_display
        self.text_original = text_original
        self.like_count = like_count
    def __getitem__(self, index):
        if index == 0:
            return self.comment_id
        elif index == 1:
            return self.text_display
        elif index == 2:
            return self.text_original
        elif index == 3:
            return self.like_count
        else:
            raise IndexError("Index out of range")

# %%
def get_comment_via_videoID(youtube, videoId, pageToken=''):
    request = youtube.commentThreads().list(
        part="snippet",
        videoId=videoId,
        maxResults=100,
        pageToken=pageToken
    )
    payload = request.execute()
    yield from payload["items"]
    # get the next page token, if there is one - which indicates there is another page.
    next_page_token = payload.get("nextPageToken")
    if next_page_token is not None:
        # recursion
        yield from get_comment_via_videoID(youtube, videoId, next_page_token)
        
    # we return a dict here of top-level-comments
    return payload

# method call
our_response = get_comment_via_videoID(youtube, 'C2ati-TugBU')

# %%
our_response_list =[]

for item in our_response:
    our_response_list.append(item)
    
# let's take a quick look at the list
our_response_list[0]

# %%
stored_details = []
# store objects of comment details into empty list
for i in range(len(our_response_list)):
    toplevelcomment = our_response_list[i]['snippet']['topLevelComment']['snippet']
    stored_details.append(
        comment_details(our_response_list[i]['id'],
                        toplevelcomment['textDisplay'],
                        toplevelcomment['textOriginal'],
                        toplevelcomment['likeCount']))

# %% [markdown]
# -------------------------------------------------------------------------------------------------------------------
# ##### We know how to get top level comments, now, let's write a method to retrieve the replies to these top-level comments.
# * We will be using a linked list to store each comment.
# * The head of each list will be the top level comment, and the following nodes will be the replies to such comment.
# * We will be taking in the like count as well as the originalDisplay of each comment for further analysis.
# -------------------------------------------------------------------------------------------------------------------
# ###### Now let's make a custom linkedlist class for our purpose
# -------------------------------------------------------------------------------------------------------------------

# %%
# our nodes
class CommentNode:
    def __init__(self, text_display, text_original, like_count):
        self.text_display = text_display
        self.text_original = text_original
        self.like_count = like_count + 1
        self.next = None

# %% [markdown]
# * The total likes will be used to 'weight' the comments based on significance.
# * I am assuming that each like on a comment is the same comment repeated once, hence why +1

# %%
# linked list implementation
class CommentLinkedList:
    def __init__(self):
        self.head = None
        self.total_likes = 0;
        
    def add_comment(self, comment_node):
        self.total_likes = (self.total_likes + comment_node.like_count)
        if not self.head:
            self.head = comment_node
        else:
            current = self.head
            while current.next:
                current = current.next
            current.next = comment_node

    def display_comments(self):
        current = self.head
        while current:
            print(f'Comment: {current.text_original}, Likes: {current.like_count}')
            current = current.next

# %% [markdown]
# ##### Let's write a method to retrieve all the replies to a specific top_level_comment

# %%
def getReplies(youtube, parentId, pageToken=''):
    request = youtube.comments().list(
        part="snippet",
        maxResults=100,
        parentId=parentId,
        pageToken=pageToken
    )
    payload = request.execute()
    yield from payload["items"]
    # get the next page token, if there is one - which indicates there is another page.
    next_page_token = payload.get("nextPageToken")
    if next_page_token is not None:
        # recursion
        yield from getReplies(youtube, videoId, next_page_token)

    # we return a dict here of top-level-comments
    return payload

# %%
all_linked_lists = []
for top_level_comments in stored_details:
    # create a linked list for each top-level comment
    comment_list = CommentLinkedList()
    # head node
    head = CommentNode(top_level_comments[1], top_level_comments[2], top_level_comments[3])
    comment_list.add_comment(head)
    # the replies
    replies = getReplies(youtube, top_level_comments[0])
    for reply in replies:
        # make node for each comment
        reply_node = CommentNode(reply['snippet']['textDisplay'], reply['snippet']['textOriginal'], reply['snippet']['likeCount'])
        comment_list.add_comment(reply_node)
    # add the completed linked list to the list
    all_linked_lists.append(comment_list)

# %%
all_linked_lists[0].total_likes
# Out:
# 44

# %% [markdown]
# ##### now our linkedlists are complete and populated with replies, we will now be conducting sentiment analysis on the comments for each top comment and their replies
#
# ##### We will use both VADER and Hugging Face to conduct sentiment analysis

# %%
import numpy as np
import pandas as pd
# VADER - doesn't get sarcasm
from nltk.sentiment import SentimentIntensityAnalyzer
from tqdm.notebook import tqdm
# Hugging face - gets sarcasm
from transformers import AutoTokenizer
from transformers import AutoModelForSequenceClassification
from scipy.special import softmax

# %% [markdown]
# -------------------------------------------------------------------------------------------------------------------
#
# ### VADER - unweighted
# -------------------------------------------------------------------------------------------------------------------

# %%
# download the datasets/models from nltk
import nltk
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/williamyang/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
# Function to traverse the LinkedList and conduct sentiment analysis without weights
def analyze_comments_VADER(linked_list):
    analyzer = SentimentIntensityAnalyzer()
    comments_data = []

    current = linked_list.head
    while current:
        scores = analyzer.polarity_scores(current.text_original)
        # Calculate non-weighted scores
        non_weighted_scores = {
                'Comment': current.text_original,
                'Negative': scores['neg'],
                'Neutral': scores['neu'],
                'Positive': scores['pos'],
                'Sentiment': scores['compound'],
                'Like Count': current.like_count
        }
        comments_data.append(non_weighted_scores)
        # Traverse linked list
        current = current.next

    df = pd.DataFrame(comments_data, columns=['Comment', 'Negative', 'Neutral', 'Positive', 'Sentiment', 'Like Count'])
    return df

# %%
# Initialize empty dataframes
VADER_df = pd.DataFrame()

# Analyze the comments and get the DataFrame
for i in range(len(all_linked_lists)):
    print('analyzing comment thread', i)
    temp = analyze_comments_VADER(all_linked_lists[i])  # Get the individual scores
    VADER_df = pd.concat([VADER_df, temp], axis=0, ignore_index=True)

# Display the DataFrames
print(VADER_df)
# Out:
# analyzing comment thread 0
# analyzing comment thread 1
# analyzing comment thread 2
# analyzing comment thread 3
# analyzing comment thread 4
# analyzing comment thread 5
# analyzing comment thread 6
# analyzing comment thread 7
# analyzing comment thread 8
# analyzing comment thread 9
# analyzing comment thread 10
# analyzing comment thread 11
# analyzing comment thread 12
# analyzing comment thread 13
# analyzing comment thread 14
# analyzing comment thread 15
# analyzing comment thread 16
# analyzing comment thread 17
# analyzing comment thread 18
# analyzing comment thread 19
# analyzing comment thread 20
# analyzing comment thread 21
# analyzing comment thread 22
# analyzing comment thread 23
# analyzing comment thread 24
# analyzing comment thread 25
# analyzing comment thread 26
# analyzing comment thread 27
# analyzing comment thread 28
# analyzing comment thread 29
# analyzing comment thread 30
# analyzing comment thread 31
# analyzing comment thread 32
# analyzing comment thread 33
# analyzing comment thread 34
# analyzing comment thread 35
# analyzing comment thread 36
# analyzing comment thread 37
# analyzing comment thread 38
# analyzing comment thread 39
# analyzing comment thread 40
# analyzing comment thread 41
# analyzing comment thread 42
# analyzing comment thread 43
# analyzing comment thread 44
# analyzing comment thread 45
# analyzing comment thread 46
# analyzing comment thread 47
# analyzing comment thread 48
# analyzing comment thread 49
# analyzing comment thread 50
# analyzing comment thread 51
# analyzing comment thread 52
# analyzing comment thread 53
# analyzing comment thread 54
# analyzing comment thread 55
# analyzing comment thread 56
# analyzing comment thread 57
# analyzing comment thread 58
# analyzing comment thread 59
# analyzing comment thread 60
# analyzing comment thread 61
# analyzing comment thread 62
# analyzing comment thread 63
# analyzing comment thread 64
# analyzing comment thread 65
# analyzing comment thread 66
# analyzing comment thread 67
# analyzing comment thread 68
# analyzing comment thread 69
# analyzing comment thread 70
# analyzing comment thread 71
# analyzing comment thread 72
# analyzing comment thread 73
# analyzing comment thread 74
# analyzing comment thread 75
# analyzing comment thread 76
# analyzing comment thread 77
# analyzing comment thread 78
# analyzing comment thread 79
# analyzing comment thread 80
# analyzing comment thread 81
# analyzing comment thread 82
# analyzing comment thread 83
# analyzing comment thread 84
# analyzing comment thread 85
# analyzing comment thread 86
# analyzing comment thread 87
# analyzing comment thread 88
# analyzing comment thread 89
# analyzing comment thread 90
# analyzing comment thread 91
# analyzing comment thread 92
# analyzing comment thread 93
# analyzing comment thread 94
# analyzing comment thread 95
# analyzing comment thread 96
# analyzing comment thread 97
# analyzing comment thread 98
# analyzing comment thread 99
# analyzing comment thread 100
# analyzing comment thread 101
# analyzing comment thread 102
# analyzing comment thread 103
# analyzing comment thread 104
# analyzing comment thread 105
# analyzing comment thread 106
# analyzing comment thread 107
# analyzing comment thread 108
# analyzing comment thread 109
# analyzing comment thread 110
# analyzing comment thread 111
# analyzing comment thread 112
# analyzing comment thread 113
# analyzing comment thread 114
# analyzing comment thread 115
# analyzing comment thread 116
# analyzing comment thread 117
# analyzing comment thread 118
# analyzing comment thread 119
# analyzing comment thread 120
# analyzing comment thread 121
# analyzing comment thread 122
# analyzing comment thread 123
# analyzing comment thread 124
# analyzing comment thread 125
# analyzing comment thread 126
# analyzing comment thread 127
# analyzing comment thread 128
# analyzing comment thread 129
# analyzing comment thread 130
# analyzing comment thread 131
# analyzing comment thread 132
# analyzing comment thread 133
# analyzing comment thread 134
# analyzing comment thread 135
# analyzing comment thread 136
# analyzing comment thread 137
# analyzing comment thread 138
# analyzing comment thread 139
# analyzing comment thread 140
# analyzing comment thread 141
# analyzing comment thread 142
# analyzing comment thread 143
# analyzing comment thread 393
# analyzing comment thread 394
# analyzing comment thread 395
# analyzing comment thread 396
# analyzing comment thread 397
# analyzing comment thread 398
# analyzing comment thread 399
# analyzing comment thread 400
# analyzing comment thread 401
# analyzing comment thread 402
# analyzing comment thread 403
# analyzing comment thread 404
# analyzing comment thread 405
# analyzing comment thread 406
# analyzing comment thread 407
# analyzing comment thread 408
# analyzing comment thread 409
# analyzing comment thread 410
# analyzing comment thread 411
# analyzing comment thread 412
# analyzing comment thread 413
# analyzing comment thread 414
# analyzing comment thread 415
# analyzing comment thread 416
# analyzing comment thread 417
# analyzing comment thread 418
# analyzing comment thread 419
# analyzing comment thread 420
# analyzing comment thread 421
# analyzing comment thread 422
# analyzing comment thread 423
# analyzing comment thread 424
# analyzing comment thread 425
# analyzing comment thread 426
# analyzing comment thread 427
# analyzing comment thread 428
# analyzing comment thread 429
# analyzing comment thread 430
# analyzing comment thread 431
# analyzing comment thread 432
# analyzing comment thread 433
# analyzing comment thread 434
# analyzing comment thread 435
# analyzing comment thread 436
# analyzing comment thread 437
# analyzing comment thread 438
# analyzing comment thread 439
# analyzing comment thread 440
# analyzing comment thread 441
# analyzing comment thread 442
# analyzing comment thread 443
# analyzing comment thread 444
# analyzing comment thread 445
# analyzing comment thread 446
# analyzing comment thread 447
# analyzing comment thread 448
# analyzing comment thread 449
# analyzing comment thread 450
# analyzing comment thread 451
# analyzing comment thread 452
# analyzing comment thread 453
# analyzing comment thread 454
# analyzing comment thread 455
# analyzing comment thread 456
# analyzing comment thread 457
# analyzing comment thread 458
#                                                Comment  Negative  Neutral  \
# 0    Subscribe and hit the bell icon so you don't m...     0.000    0.904
# 1    The bankers always have several " Epsteins " a...     0.024    0.810
# 2    #VICE ...  if you cant figure out which place ...     0.000    1.000
# 3                        Is this company still afloat?     0.000    1.000
# 4          Clown show .how the f**k did I end up here.     0.000    1.000
# ..                                                 ...       ...      ...
# 770  Who wants to participate in an adrenochrome dr...     0.000    0.828
# 771  -Come over an see \nJohnny\n Depp \nthreatens\...     0.148    0.852
# 772  You guys really tried your best to use all the...     0.257    0.642
# 773  It’s stuff like this is why soros had to buy y...     0.000    0.823
# 774  You have to be an idiot to think Epstein died ...     0.235    0.673
#
#      Positive  Sentiment  Like Count
# 0       0.096     0.1798          32
# 1       0.166     0.8591           1
# 2       0.000     0.0000           1
# 3       0.000     0.0000           1
# 4       0.000     0.0000           1
# ..        ...        ...         ...
# 770     0.172     0.4019           1
# 771     0.000    -0.3818           1
# 772     0.101    -0.8674           1
# 773     0.177     0.6808           1
# 774     0.092    -0.9554           1
#
# [775 rows x 6 columns]

# %% [markdown]
# Let's get the average sentiment of the comment section via average of Sentiment column

# %%
unweighted_VADER_result = VADER_df['Sentiment'].mean()

# %% [markdown]
# -------------------------------------------------------------------------------------------------------------------
#
# ### VADER - weighted
# -------------------------------------------------------------------------------------------------------------------

# %%
# first let us get the total amount of likes within the entire comment section
total_likes_in_comment_section = 0
for linked_list in all_linked_lists:
    total_likes_in_comment_section+=linked_list.total_likes
print(total_likes_in_comment_section)
# Out:
# 5430

# %% [markdown]
# * We will apply the weights (like count) on the Sentiment value of each comment then average it out

# %%
# Define a function to multiply sentiment and like_count and return the result
def multiply_columns(row):
    return row['Sentiment'] * row['Like Count']

# %%
VADER_df['weighted_sentiment'] = VADER_df.apply(multiply_columns, axis=1)

# %%
weighted_VADER_result = VADER_df['weighted_sentiment'].sum()/total_likes_in_comment_section

# %% [markdown]
# -------------------------------------------------------------------------------------------------------------------
#
# ### ROBERTA Hugging face
#
# -------------------------------------------------------------------------------------------------------------------

# %%
# we will use a pre-trained model for this
MODEL = f"cardiffnlp/twitter-roberta-base-sentiment"
tokenizer = AutoTokenizer.from_pretrained(MODEL)
model = AutoModelForSequenceClassification.from_pretrained(MODEL)

# %%
# Function to traverse the LinkedList and conduct sentiment analysis with ROBERTA
def analyze_comments_ROBERTA(linked_list):
    comments_data = []
    current = linked_list.head
    while current:
        encoded_text = tokenizer(current.text_original, return_tensors='pt', max_length=512, truncation=True)
        output = model(**encoded_text)
        scores = output[0][0].detach().numpy()
        scores = softmax(scores)
        items = {
        'Comment': current.text_original,
        'Negative': scores[0],
        'Neutral': scores[1],
        'Positive': scores[2],
        'Like Count': current.like_count
        }
        comments_data.append(items)
        # Traverse linked list
        current = current.next

    df = pd.DataFrame(comments_data, columns=['Comment','Negative','Neutral','Positive','Like Count'])
    return df

# %%
ROBERTA_df = pd.DataFrame()
for i in range(len(all_linked_lists)):
    print('analyzing comment thread', i)
    temp = analyze_comments_ROBERTA(all_linked_lists[i])
    ROBERTA_df = pd.concat([ROBERTA_df, temp], axis=0, ignore_index=True)

ROBERTA_df
# Out:
# analyzing comment thread 0
# analyzing comment thread 1
# analyzing comment thread 2
# analyzing comment thread 3
# analyzing comment thread 4
# analyzing comment thread 5
# analyzing comment thread 6
# analyzing comment thread 7
# analyzing comment thread 8
# analyzing comment thread 9
# analyzing comment thread 10
# analyzing comment thread 11
# analyzing comment thread 12
# analyzing comment thread 13
# analyzing comment thread 14
# analyzing comment thread 15
# analyzing comment thread 16
# analyzing comment thread 17
# analyzing comment thread 18
# analyzing comment thread 19
# analyzing comment thread 20
# analyzing comment thread 21
# analyzing comment thread 22
# analyzing comment thread 23
# analyzing comment thread 24
# analyzing comment thread 25
# analyzing comment thread 26
# analyzing comment thread 27
# analyzing comment thread 28
# analyzing comment thread 29
# analyzing comment thread 30
# analyzing comment thread 31
# analyzing comment thread 32
# analyzing comment thread 33
# analyzing comment thread 34
# analyzing comment thread 35
# analyzing comment thread 36
# analyzing comment thread 37
# analyzing comment thread 38
# analyzing comment thread 39
# analyzing comment thread 40
# analyzing comment thread 41
# analyzing comment thread 42
# analyzing comment thread 43
# analyzing comment thread 44
# analyzing comment thread 45
# analyzing comment thread 46
# analyzing comment thread 47
# analyzing comment thread 48
# analyzing comment thread 49
# analyzing comment thread 50
# analyzing comment thread 51
# analyzing comment thread 52
# analyzing comment thread 53
# analyzing comment thread 54
# analyzing comment thread 55
# analyzing comment thread 56
# analyzing comment thread 57
# analyzing comment thread 58
# analyzing comment thread 59
# analyzing comment thread 60
# analyzing comment thread 61
# analyzing comment thread 62
# analyzing comment thread 312
# analyzing comment thread 313
# analyzing comment thread 314
# analyzing comment thread 315
# analyzing comment thread 316
# analyzing comment thread 317
# analyzing comment thread 318
# analyzing comment thread 319
# analyzing comment thread 320
# analyzing comment thread 321
# analyzing comment thread 322
# analyzing comment thread 323
# analyzing comment thread 324
# analyzing comment thread 325
# analyzing comment thread 326
# analyzing comment thread 327
# analyzing comment thread 328
# analyzing comment thread 329
# analyzing comment thread 330
# analyzing comment thread 331
# analyzing comment thread 332
# analyzing comment thread 333
# analyzing comment thread 334
# analyzing comment thread 335
# analyzing comment thread 336
# analyzing comment thread 337
# analyzing comment thread 338
# analyzing comment thread 339
# analyzing comment thread 340
# analyzing comment thread 341
# analyzing comment thread 342
# analyzing comment thread 343
# analyzing comment thread 344
# analyzing comment thread 345
# analyzing comment thread 346
# analyzing comment thread 347
# analyzing comment thread 348
# analyzing comment thread 349
# analyzing comment thread 350
# analyzing comment thread 351
# analyzing comment thread 352
# analyzing comment thread 353
# analyzing comment thread 354
# analyzing comment thread 355
# analyzing comment thread 356
# analyzing comment thread 357
# analyzing comment thread 358
# analyzing comment thread 359
# analyzing comment thread 360
# analyzing comment thread 361
# analyzing comment thread 362
# analyzing comment thread 363
# analyzing comment thread 364
# analyzing comment thread 365
# analyzing comment thread 366
# analyzing comment thread 367
# analyzing comment thread 368
# analyzing comment thread 369
# analyzing comment thread 370
# analyzing comment thread 371
# analyzing comment thread 372
# analyzing comment thread 373
# analyzing comment thread 374
# analyzing comment thread 375
# analyzing comment thread 376
# analyzing comment thread 377
# analyzing comment thread 378
# analyzing comment thread 379
# analyzing comment thread 380
# analyzing comment thread 381
# analyzing comment thread 382
# analyzing comment thread 383
# analyzing comment thread 384
# analyzing comment thread 385
# analyzing comment thread 386
# analyzing comment thread 387
# analyzing comment thread 388
# analyzing comment thread 389
# analyzing comment thread 390
# analyzing comment thread 391
# analyzing comment thread 392
# analyzing comment thread 393
# analyzing comment thread 394
# analyzing comment thread 395
# analyzing comment thread 396
# analyzing comment thread 397
# analyzing comment thread 398
# analyzing comment thread 399
# analyzing comment thread 400
# analyzing comment thread 401
# analyzing comment thread 402
# analyzing comment thread 403
# analyzing comment thread 404
# analyzing comment thread 405
# analyzing comment thread 406
# analyzing comment thread 407
# analyzing comment thread 408
# analyzing comment thread 409
# analyzing comment thread 410
# analyzing comment thread 411
# analyzing comment thread 412
# analyzing comment thread 413
# analyzing comment thread 414
# analyzing comment thread 415
# analyzing comment thread 416
# analyzing comment thread 417
# analyzing comment thread 418
# analyzing comment thread 419
# analyzing comment thread 420
# analyzing comment thread 421
# analyzing comment thread 422
# analyzing comment thread 423
# analyzing comment thread 424
# analyzing comment thread 425
# analyzing comment thread 426
# analyzing comment thread 427
# analyzing comment thread 428
# analyzing comment thread 429
# analyzing comment thread 430
# analyzing comment thread 431
# analyzing comment thread 432
# analyzing comment thread 433
# analyzing comment thread 434
# analyzing comment thread 435
# analyzing comment thread 436
# analyzing comment thread 437
# analyzing comment thread 438
# analyzing comment thread 439
# analyzing comment thread 440
# analyzing comment thread 441
# analyzing comment thread 442
# analyzing comment thread 443
# analyzing comment thread 444
# analyzing comment thread 445
# analyzing comment thread 446
# analyzing comment thread 447
# analyzing comment thread 448
# analyzing comment thread 449
# analyzing comment thread 450
# analyzing comment thread 451
# analyzing comment thread 452
# analyzing comment thread 453
# analyzing comment thread 454
# analyzing comment thread 455
# analyzing comment thread 456
# analyzing comment thread 457
# analyzing comment thread 458
#                                                Comment  Negative   Neutral  \
# 0    Subscribe and hit the bell icon so you don't m...  0.031425  0.449961
# 1    The bankers always have several " Epsteins " a...  0.438680  0.507708
# 2    #VICE ...  if you cant figure out which place ...  0.829127  0.160327
# 3                        Is this company still afloat?  0.168324  0.802602
# 4          Clown show .how the f**k did I end up here.  0.963522  0.029907
# ..                                                 ...       ...       ...
# 770  Who wants to participate in an adrenochrome dr...  0.014603  0.850504
# 771  -Come over an see \nJohnny\n Depp \nthreatens\...  0.513318  0.460983
# 772  You guys really tried your best to use all the...  0.831935  0.160507
# 773  It’s stuff like this is why soros had to buy y...  0.925011  0.066369
# 774  You have to be an idiot to think Epstein died ...  0.769112  0.210577
#
#      Positive  Like Count
# 0    0.518614          32
# 1    0.053612           1
# 2    0.010546           1
# 3    0.029075           1
# 4    0.006571           1
# ..        ...         ...
# 770  0.134893           1
# 771  0.025698           1
# 772  0.007558           1
# 773  0.008621           1
# 774  0.020311           1
#
# [775 rows x 5 columns]

# %%
# Define a function to calculate sentiment score for ROBERTA
def get_sentiment(row):
    return ((-1) * row['Negative'] + row['Positive'])

# %%
# now let's get the sentiment scores for ROBERTA
ROBERTA_df['Sentiment'] = ROBERTA_df.apply(get_sentiment, axis=1)

# %% [markdown]
# * assuming that -1 being most negative and 1 being most positive, within a perfect scenario, a comment with negative score of 1 would have positive and netural score of 0, and a comment with positive score of 1 would have negative and netural score of 0.
# * To get a 'sentiment' score between -1 and 1, we will be flipping the negative score, ignoring the netural score, then returning the sum of the three values.

# %%
unweighted_ROBERTA_result = ROBERTA_df['Sentiment'].mean()

# %% [markdown]
# * now let's get the weighted avg sentiment

# %%
ROBERTA_df['weighted_sentiment'] = ROBERTA_df.apply(multiply_columns, axis=1)
weighted_ROBERTA_result = ROBERTA_df['weighted_sentiment'].sum()/total_likes_in_comment_section

# %% [markdown]
# -------------------------------------------------------------------------------------------------------------------
#
# ### Results:
#
# -------------------------------------------------------------------------------------------------------------------

# %%
data = {
    'unweighted_VADER_result': [unweighted_VADER_result],
    'weighted_VADER_result': [weighted_VADER_result],
    'unweighted_ROBERTA_result' : [unweighted_ROBERTA_result],
    'weighted_ROBERTA_result': [weighted_ROBERTA_result]
}

results_df = pd.DataFrame(data)
results_df
# Out:
#    unweighted_VADER_result  weighted_VADER_result  unweighted_ROBERTA_result  \
# 0                 0.025422               -0.01079                  -0.347983
#
#    weighted_ROBERTA_result
# 0                -0.262583

# %% [markdown]
# * let's plot the results to compare

# %%
import matplotlib.pyplot as plt

# %%
# Plotting
results_df.plot(kind='bar', figsize=(10, 6))

plt.title('Sentiment Analysis Results')
plt.ylabel('Scores')
plt.xlabel('Methods')

plt.show()

# %% [markdown]
# -------------------------------------------------------------------------------------------------------------------
#
# ### Analysis:
#
# -------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# * We can clearly see that the ROBERTA results are significantly more negative compared to the VADER results. This could be attributed to how the different models work.
# -------------------------------------------------------------------------------------------------------------------
# * VADER uses a combination of a sentiment lexicon, which is a list of words which are generally labeled according to their semantic orientation as either positive or negative.
# * The VADER model used was trained on 9,000 tokens/words, as mention here: https://github.com/cjhutto/vaderSentiment/blob/master/README.rst
# -------------------------------------------------------------------------------------------------------------------
# * The ROBERTA model takes a deep learning approach where the model is trained on a large corpus of text, 58M in this case, and then fine-tuned for sentiment analysis tasks.
# https://huggingface.co/cardiffnlp/twitter-roberta-base-sentiment
# -------------------------------------------------------------------------------------------------------------------
# * Basically, I think that VADER is a quick and resource-effecient tool to get a general sentiment on a short text, however it falls short when text being analyzed becomes too complex.
# -------------------------------------------------------------------------------------------------------------------
# * ROBERTA is the exact opposite, it's slower, takes more resources, yet it is generally more accurate due to it's fine-tuning. It is best used on long, complex texts, and in our case youtube comments do fit that critera most of the time.

# %% [markdown]
# -------------------------------------------------------------------------------------------------------------------
# ###### From now on, we will be using ROBERTA for our analysis
# ###### Before we go any further, let's make another plot for the ROBERTA method, let's plot all the comments and their scores and measure variance too, for both weighted and unweighted case.
# -------------------------------------------------------------------------------------------------------------------

# %%
import matplotlib.pyplot as plt
# each bar is 0.01 apart, as per the number of bins 2/200=0.01
ROBERTA_df['Sentiment'].hist(bins=200)
plt.xlabel('Sentiment')
plt.ylabel('Frequency')
plt.title('Histogram of Sentiment')
plt.show()

# %%
ROBERTA_df
# Out:
#                                                Comment  Negative   Neutral  \
# 0    Subscribe and hit the bell icon so you don't m...  0.031425  0.449961
# 1    The bankers always have several " Epsteins " a...  0.438680  0.507708
# 2    #VICE ...  if you cant figure out which place ...  0.829127  0.160327
# 3                        Is this company still afloat?  0.168324  0.802602
# 4          Clown show .how the f**k did I end up here.  0.963522  0.029907
# ..                                                 ...       ...       ...
# 770  Who wants to participate in an adrenochrome dr...  0.014603  0.850504
# 771  -Come over an see \nJohnny\n Depp \nthreatens\...  0.513318  0.460983
# 772  You guys really tried your best to use all the...  0.831935  0.160507
# 773  It’s stuff like this is why soros had to buy y...  0.925011  0.066369
# 774  You have to be an idiot to think Epstein died ...  0.769112  0.210577
#
#      Positive  Like Count  Sentiment  weighted_sentiment
# 0    0.518614          32   0.487189           15.590038
# 1    0.053612           1  -0.385068           -0.385068
# 2    0.010546           1  -0.818581           -0.818581
# 3    0.029075           1  -0.139249           -0.139249
# 4    0.006571           1  -0.956951           -0.956951
# ..        ...         ...        ...                 ...
# 770  0.134893           1   0.120290            0.120290
# 771  0.025698           1  -0.487620           -0.487620
# 772  0.007558           1  -0.824377           -0.824377
# 773  0.008621           1  -0.916390           -0.916390
# 774  0.020311           1  -0.748801           -0.748801
#
# [775 rows x 7 columns]

# %% [markdown]
# # now getting uploads

# %%
import os
import googleapiclient.discovery
# here is our API key and other items
youtube_api_key = 'AIzaSyBaFhDvztf8hwgX4DWxTRdbmcqKbEkr6-A'
api_service_name = "youtube"
api_version = "v3"
channelId = 'UCqnbDFdCpuN8CMEg0VuEBqA'

# %%
    request = youtube.channels().list(
        part="contentDetails",
        forUsername="TheNewYorkTimes"
    )
    response = request.execute()

    print(response)
# Out:
# {'kind': 'youtube#channelListResponse', 'etag': 'RlSxQuRLVXpFy9QLvoGyEhMtpJo', 'pageInfo': {'totalResults': 1, 'resultsPerPage': 5}, 'items': [{'kind': 'youtube#channel', 'etag': 'nMqbtROs2BKpIctpth0Wab6424s', 'id': 'UCqnbDFdCpuN8CMEg0VuEBqA', 'contentDetails': {'relatedPlaylists': {'likes': '', 'uploads': 'UUqnbDFdCpuN8CMEg0VuEBqA'}}}]}

# %%
response
# Out:
# {'kind': 'youtube#channelListResponse',
#  'etag': 'RlSxQuRLVXpFy9QLvoGyEhMtpJo',
#  'pageInfo': {'totalResults': 1, 'resultsPerPage': 5},
#  'items': [{'kind': 'youtube#channel',
#    'etag': 'nMqbtROs2BKpIctpth0Wab6424s',
#    'id': 'UCqnbDFdCpuN8CMEg0VuEBqA',
#    'contentDetails': {'relatedPlaylists': {'likes': '',
#      'uploads': 'UUqnbDFdCpuN8CMEg0VuEBqA'}}}]}

# %%
import requests
import time
import json
from datetime import datetime, timedelta


# logic:
# when initialized, run a query to get all the videos currently in a channel, and save it as a base line 'old_videos'

# this file will then conduct routine API calls to get all the videos currently in a channel and 
# check if there is a difference in the videos returned

# if there is a difference, then that must mean a new video has been uploaded. 
# we will then store the video ID of said video, and run a sentiment calculation after a set period of time.


# first get the playlist Id of the 'uploads' playlist.
def getUploadsPlaylistId(youtube, channelName):
    request = youtube.channels().list(
        part="contentDetails",
        forUsername=channelName
    )
    response = request.execute()
    # etag field is the Channel ID
    return response['items'][-1]['contentDetails']['relatedPlaylists']['uploads']

# method that should only run ONCE, to first get all the videos id's 
def getAllVideos(youtube, channelName):
    # get the upload playlist ID
    uploadsPlaylistId = getUploadsPlaylistId(youtube, channelName)
    # use that ID, to retrieve all videos within it
    our_old_videos = get_all_videoIds_in_uploadPlayList(youtube, uploadsPlaylistId)
    return our_old_videos


def get_videoIds_from_uploadPlayListId(youtube, uploadPlaylistId, page_token=None):
    # request information
    request = youtube.playlistItems().list(
        part="id",
        playlistId=uploadPlaylistId,
        pageToken=page_token,
        maxResults=100,
    )
    response = request.execute()
    # put response into variable (after parsing)
    return response


# method to retrieve all items in the playlist, going to next page if needed.
# *returns lots of dicts*
def get_all_videoIds_in_uploadPlayList(youtube, uploadPlaylistId, page_token=None):
    payload = get_videoIds_from_uploadPlayListId(youtube, uploadPlaylistId, page_token)
    for item in payload["items"]:
        yield item['contentDetails']['videoId']  
  

    next_page_token = payload.get("nextPageToken")
    if next_page_token is not None:
        yield from get_all_videoIds_in_uploadPlayList(youtube, uploadPlaylistId, next_page_token)

# %%
testing = getAllVideos(youtube, 'Pocketpair')

list_of_playlistitems =[]
for i in testing:
    list_of_playlistitems.append(i)
print(list_of_playlistitems)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 testing = getAllVideos(youtube, 'Pocketpair')
#       2 list_of_playlistitems =[]
#       3 for i in testing:
#
# Cell In[42], line 30, in getAllVideos(youtube, channelName)
#      28 def getAllVideos(youtube, channelName):
#      29     # get the upload playlist ID
# ---> 30     uploadsPlaylistId = getUploadsPlaylistId(youtube, channelName)
#      31     # use that ID, to retrieve all videos within it
#      32     our_old_videos = get_all_videoIds_in_uploadPlayList(youtube, uploadsPlaylistId)
#
# Cell In[42], line 25, in getUploadsPlaylistId(youtube, channelName)
#      23 response = request.execute()
#      24 # etag field is the Channel ID
# ---> 25 return response['items'][-1]['contentDetails']['relatedPlaylists']['uploads']
#
# KeyError: 'items'

# %%
# first get the channelId of the 'uploads' playlist.
def getChannelId_with_SEARCH(youtube, channelName):
    request = youtube.search().list(
        part="snippet",
        channelType="any",
        q=channelName
    )
    response = request.execute()

    print(response)
    # return just the channelId
    return response['items'][0]['snippet']['channelId']

# %%
query = getChannelId(youtube, 'The New York Times')
# Out:
# {'kind': 'youtube#searchListResponse', 'etag': '6FTvzc8HvKOzGs_lpOXVLzLhaJQ', 'nextPageToken': 'CAUQAA', 'regionCode': 'US', 'pageInfo': {'totalResults': 1000000, 'resultsPerPage': 5}, 'items': [{'kind': 'youtube#searchResult', 'etag': 'sHtzi68AVSqsRoUl54-H-9oIewc', 'id': {'kind': 'youtube#channel', 'channelId': 'UCqnbDFdCpuN8CMEg0VuEBqA'}, 'snippet': {'publishedAt': '2006-10-13T21:57:36Z', 'channelId': 'UCqnbDFdCpuN8CMEg0VuEBqA', 'title': 'The New York Times', 'description': 'The New York Times is the most powerful engine for independent, boots-on-the-ground and deeply reported journalism. We set ...', 'thumbnails': {'default': {'url': 'https://yt3.ggpht.com/ytc/AIf8zZQQO7YMhHsIwrJIBt_oU416-lNOMUI0Zy4DdjSV-g=s88-c-k-c0xffffffff-no-rj-mo'}, 'medium': {'url': 'https://yt3.ggpht.com/ytc/AIf8zZQQO7YMhHsIwrJIBt_oU416-lNOMUI0Zy4DdjSV-g=s240-c-k-c0xffffffff-no-rj-mo'}, 'high': {'url': 'https://yt3.ggpht.com/ytc/AIf8zZQQO7YMhHsIwrJIBt_oU416-lNOMUI0Zy4DdjSV-g=s800-c-k-c0xffffffff-no-rj-mo'}}, 'channelTitle': 'The New York Times', 'liveBroadcastContent': 'none', 'publishTime': '2006-10-13T21:57:36Z'}}, {'kind': 'youtube#searchResult', 'etag': '1-LhELf3iGL8-TKY0R4zAXLhyxo', 'id': {'kind': 'youtube#video', 'videoId': 'W9mPEquFKKA'}, 'snippet': {'publishedAt': '2024-01-24T18:00:26Z', 'channelId': 'UCqnbDFdCpuN8CMEg0VuEBqA', 'title': 'We Need to Get Back to 1980 on Immigration | NYT Opinion', 'description': "Why have Republicans and Democrats moved so far apart on immigration? That's the question that drives the Opinion video ...", 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/W9mPEquFKKA/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/W9mPEquFKKA/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/W9mPEquFKKA/hqdefault.jpg', 'width': 480, 'height': 360}}, 'channelTitle': 'The New York Times', 'liveBroadcastContent': 'none', 'publishTime': '2024-01-24T18:00:26Z'}}, {'kind': 'youtube#searchResult', 'etag': 'EOK6Iu8fC1yX5OOxZaSwsCHMDTc', 'id': {'kind': 'youtube#video', 'videoId': 'o_GPSEVEasE'}, 'snippet': {'publishedAt': '2024-01-23T18:00:57Z', 'channelId': 'UCqnbDFdCpuN8CMEg0VuEBqA', 'title': 'Watch the Opening Scene of ‘Oppenheimer’ | Anatomy of a Scene', 'description': "Raindrops help usher in the opening moments of “Oppenheimer,” Christopher Nolan's ambitious, Oscar-nominated biopic about J.", 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/o_GPSEVEasE/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/o_GPSEVEasE/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/o_GPSEVEasE/hqdefault.jpg', 'width': 480, 'height': 360}}, 'channelTitle': 'The New York Times', 'liveBroadcastContent': 'none', 'publishTime': '2024-01-23T18:00:57Z'}}, {'kind': 'youtube#searchResult', 'etag': 'uQKa2MWtw9b3CfVXWgSRZ9PVsCU', 'id': {'kind': 'youtube#video', 'videoId': 'n60NTrKs-wc'}, 'snippet': {'publishedAt': '2023-08-14T13:00:41Z', 'channelId': 'UCqnbDFdCpuN8CMEg0VuEBqA', 'title': '‘His Name Was Bélizaire’: Rare Portrait of Enslaved Child Arrives at the Met', 'description': 'The Met recently acquired “Bélizaire and the Frey Children,” a 19th-century Louisiana portrait with a secret: For over a 100 years, ...', 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/n60NTrKs-wc/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/n60NTrKs-wc/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/n60NTrKs-wc/hqdefault.jpg', 'width': 480, 'height': 360}}, 'channelTitle': 'The New York Times', 'liveBroadcastContent': 'none', 'publishTime': '2023-08-14T13:00:41Z'}}, {'kind': 'youtube#searchResult', 'etag': 'NIEZoHJQMT-vD5nwdmqs6l8vd5c', 'id': {'kind': 'youtube#video', 'videoId': 'VVPc46GFq-4'}, 'snippet': {'publishedAt': '2023-12-21T18:00:13Z', 'channelId': 'UCqnbDFdCpuN8CMEg0VuEBqA', 'title': 'The Life Span of Loneliness | NYT Opinion', 'de ...

# %%
def getPlaylistId_with_channelId(youtube, channelId):
    request = youtube.channels().list(
        part="contentDetails",
        id=channelId
    )
    response = request.execute()

    return response['items'][0]['contentDetails']['relatedPlaylists']['uploads']

# %%
reply = getPlaylistId_with_channelId(youtube, "UCz6cOlpF6os7JkAKnpMNriw")

# %%
    request = youtube.playlistItems().list(
        part="contentDetails",
        playlistId="UUz6cOlpF6os7JkAKnpMNriw"
    )
    response = request.execute()

    print(response)
# Out:
}},
#   {'kind': 'youtube#playlistItem',
#    'etag': 'dNTpF_rNVXjwI6Dc21RlxsIGawM',
#    'id': 'VVVxbmJERmRDcHVOOENNRWcwVnVFQnFBLnYyVlV0M2w3SHk0',
#    'contentDetails': {'videoId': 'v2VUt3l7Hy4',
#     'videoPublishedAt': '2024-01-22T16:00:39Z'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': 'b7qnwP07liEdYlC_1Xvx9zFOauE',
#    'id': 'VVVxbmJERmRDcHVOOENNRWcwVnVFQnFBLi1lcHM2N2NmeEt3',
#    'contentDetails': {'videoId': '-eps67cfxKw',
#     'videoPublishedAt': '2024-01-17T18:02:00Z'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': 'nFhbUM0ObfktqPWl07OK3FABuYs',
#    'id': 'VVVxbmJERmRDcHVOOENNRWcwVnVFQnFBLjZIMHR2c3ozLXBn',
#    'contentDetails': {'videoId': '6H0tvsz3-pg',
#     'videoPublishedAt': '2024-01-17T18:00:03Z'}}],
#  'pageInfo': {'totalResults': 10140, 'resultsPerPage': 5}}

# %%
# retrieves video information using specific page_token.
def get_PlaylistItems_from_uploadPlayListId(youtube, uploadPlaylistId, page_token=None):
    # request information
    request = youtube.playlistItems().list(
        part="contentDetails",
        playlistId=uploadPlaylistId,
        pageToken=page_token,
        maxResults=100,
    )
    response = request.execute()
    # put response into variable (after parsing)
    return response

# method to retrieve all videos in a playlist, going to next page if needed.
def getAllVideoIds_with_uploadsPlaylistId(youtube, uploadPlaylistId, page_token=None):
    payload = get_PlaylistItems_from_uploadPlayListId(youtube, uploadPlaylistId, page_token)
    for item in payload["items"]:
        yield item['contentDetails']  

    next_page_token = payload.get("nextPageToken")
    if next_page_token is not None:
        yield from getAllVideoIds_with_uploadsPlaylistId(youtube, uploadPlaylistId, next_page_token)

# %%
ob = getAllVideoIds_with_uploadsPlaylistId(youtube, reply)

# %%
ob
# Out:
# <generator object getAllVideoIds_with_uploadsPlaylistId at 0x123d70e40>

# %%
emp = []
for i in ob:
    emp.append(i)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[110], line 2
#       1 emp = []
# ----> 2 for i in ob:
#       3     emp.append(i)
#
# Cell In[107], line 18, in getAllVideoIds_with_uploadsPlaylistId(youtube, uploadPlaylistId, page_token)
#      16 payload = get_PlaylistItems_from_uploadPlayListId(youtube, uploadPlaylistId, page_token)
#      17 for item in payload["items"]:
# ---> 18     yield item['contentDetails']
#      20 next_page_token = payload.get("nextPageToken")
#      21 if next_page_token is not None:
#
# KeyError: 'contentDetails'

# %%
ret = getAllVideoIds_with_uploadsPlaylistId(youtube, reply)
ret
# Out:
# <generator object getAllVideoIds_with_uploadsPlaylistId at 0x123d71540>

# %%
emp = []
for i in ret:
    emp.append(i)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[115], line 2
#       1 emp = []
# ----> 2 for i in ret:
#       3     emp.append(i)
#
# Cell In[112], line 22, in getAllVideoIds_with_uploadsPlaylistId(youtube, uploadPlaylistId, page_token)
#      20 next_page_token = payload.get("nextPageToken")
#      21 if next_page_token is not None:
# ---> 22     yield from get_all_Playlistitems_in_uploadPlayList(youtube, uploadPlaylistId, next_page_token)
#
# NameError: name 'get_all_Playlistitems_in_uploadPlayList' is not defined
